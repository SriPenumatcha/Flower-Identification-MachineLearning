# %%
# Import Dependencies
import tensorflow as tf
import numpy as np
from matplotlib import pyplot as plt
import os
import cv2

# %%
#Load data
data_dir = 'data'

# %%
#Use the Dataset API with the image_dataset_from_directory pipieline. This reduces computational load, sorts images by class and many other standard steps before image processing
data = tf.keras.utils.image_dataset_from_directory('data')
# Out:
# Found 4290 files belonging to 5 classes.

# %% [markdown]
# ## --

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)

# %%
class_names = data.class_names
print(class_names)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 class_names = data.class_names
#       2 print(class_names)
#
# AttributeError: '_MapDataset' object has no attribute 'class_names'

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ## --

# %%
data_iterator = data.as_numpy_iterator()

# %%
batch = data_iterator.next()

# %%
#Have a look at the first few images of the first batch and its corresponding classes. 
fig, ax = plt.subplots(ncols=4, figsize=(30,30))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %% [markdown]
# ## Make a few quality checks

# %%
#Check if data is loaded coorectly 
os.listdir(data_dir)
# Out:
# ['daisy', 'rose', 'tulip', 'dandelion', 'sunflower']

# %%
#Check if you have two parts of this batch, one is for images and second for labels 
len(batch[0])
# Out:
# 32

# %%
batch[0].shape
#Images are in default batch size of 32, reshaped to default 256 x 256 and in 3 channels, RGB. Images represented as Numpy arrays
# Out:
# (32, 256, 256, 3)

# %%
#Have a look at the labels of the first batch
batch[1]
# Out:
# array([2, 0, 1, 0, 4, 2, 0, 3, 3, 3, 1, 0, 1, 0, 0, 1, 3, 2, 3, 1, 2, 2,
#        0, 2, 2, 4, 4, 0, 2, 3, 0, 1], dtype=int32)

# %% [markdown]
# # Scale the Data

# %%
data = data.map(lambda x,y: (x/255, y))

# %%
data.as_numpy_iterator().next()
# Out:
# (array([[[[9.53431368e-01, 8.93137276e-01, 1.07843138e-01],
#           [7.07352936e-01, 8.14215660e-01, 1.93627447e-01],
#           [7.39215672e-01, 8.19117665e-01, 2.03431368e-01],
#           ...,
#           [7.69607842e-01, 8.28431368e-01, 2.06372544e-01],
#           [6.83823526e-01, 8.18627477e-01, 1.52450979e-01],
#           [9.54411745e-01, 8.81372571e-01, 1.03431374e-01]],
#
#          [[5.88656545e-01, 7.06441462e-01, 2.45232075e-01],
#           [2.80675553e-02, 1.22483917e-01, 9.24134493e-01],
#           [5.51432297e-02, 2.06372544e-01, 8.93248320e-01],
#           ...,
#           [1.80376843e-02, 1.57762721e-01, 9.01455283e-01],
#           [1.60271134e-02, 1.40778184e-01, 9.67210472e-01],
#           [5.45117199e-01, 6.31966174e-01, 3.49008113e-01]],
#
#          [[6.89185023e-01, 7.61312783e-01, 3.14476103e-01],
#           [6.49931058e-02, 2.12339148e-01, 8.43688726e-01],
#           [1.20216757e-01, 3.47583473e-01, 7.10550725e-01],
#           ...,
#           [1.36603862e-01, 3.58819693e-01, 7.28304982e-01],
#           [5.65257370e-02, 2.49808520e-01, 8.22840095e-01],
#           [6.30916834e-01, 7.19247878e-01, 2.89897352e-01]],
#
#          ...,
#
#          [[6.17834687e-01, 7.95982718e-01, 2.89782465e-01],
#           [3.00283395e-02, 3.11649829e-01, 9.27841604e-01],
#           [5.15510105e-02, 3.67639393e-01, 9.08482671e-01],
#           ...,
#           [1.06177233e-01, 4.19274658e-01, 9.26022530e-01],
#           [3.39882039e-02, 3.32379758e-01, 9.44041073e-01],
#           [5.95193803e-01, 7.39449322e-01, 3.45821857e-01]],
#           [7.18999267e-01, 5.39229274e-01, 2.27030441e-01],
#           [7.37985015e-01, 5.64164519e-01, 2.68775433e-01],
#           [7.32270420e-01, 5.63796997e-01, 2.66052246e-01]],
#
#          [[6.08892441e-01, 4.32421863e-01, 1.12168618e-01],
#           [6.17359042e-01, 4.40888464e-01, 1.16752416e-01],
#           [6.14499092e-01, 4.38028485e-01, 1.13447241e-01],
#           ...,
#           [7.26756454e-01, 5.47097027e-01, 2.39016488e-01],
#           [7.25946724e-01, 5.57829380e-01, 2.49229461e-01],
#           [7.26195872e-01, 5.57696581e-01, 2.58586079e-01]],
#
#          [[6.04582489e-01, 4.26536292e-01, 1.13616049e-01],
#           [6.09146237e-01, 4.32675660e-01, 1.14245303e-01],
#           [6.10612392e-01, 4.34141815e-01, 1.11654066e-01],
#           ...,
#           [7.36021757e-01, 5.53182006e-01, 2.35876232e-01],
#           [7.17473388e-01, 5.52247703e-01, 2.32238531e-01],
#           [6.92589402e-01, 5.25396407e-01, 2.12200448e-01]]]],
#        dtype=float32),
#  array([3, 2, 2, 3, 4, 1, 0, 3, 0, 1, 1, 2, 1, 1, 4, 0, 2, 1, 1, 3, 1, 2,
#         0, 2, 2, 3, 2, 1, 3, 1, 2, 4], dtype=int32))

# %% [markdown]
# ## Split Data

# %%
len(data)
# Out:
# 135

# %%
train_size = int(len(data)*.7)
val_size = int(len(data)*.2)
test_size = int(len(data)*.1)+1

# %%
print(train_size, val_size, test_size)
# Out:
# 94 27 14

# %%
train = data.take(train_size)
val = data.skip(train_size).take(val_size)
test = data.skip(train_size+val_size).take(test_size)

# %% [markdown]
# # Train

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout

# %%
# Define a simple CNN model
model = Sequential([
    Conv2D(32, (3, 3), 1, activation='relu', input_shape=(256, 256, 3)),
    MaxPooling2D(pool_size=(2, 2)),
    
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    
    Flatten(),
    
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(5, activation='softmax')
])
# Out:
# /opt/anaconda3/envs/dev/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Print model layers
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 254, 254, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 127, 127, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 125, 125, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 62, 62, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 60, 60, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 30, 30, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 115200)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │    58,982,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │         2,565 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 59,078,725 (225.37 MB)
#  Trainable params: 59,078,725 (225.37 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # Train

# %%
logdir='logs'

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
hist = model.fit(train, epochs=20, validation_data=val)
# Out:
# Epoch 1/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 99s 1s/step - accuracy: 0.3487 - loss: 2.0613 - val_accuracy: 0.5359 - val_loss: 1.1381
# Epoch 2/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 121s 1s/step - accuracy: 0.5481 - loss: 1.0786 - val_accuracy: 0.6505 - val_loss: 0.9379
# Epoch 3/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 102s 1s/step - accuracy: 0.6832 - loss: 0.8549 - val_accuracy: 0.6493 - val_loss: 0.9649
# Epoch 4/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 119s 1s/step - accuracy: 0.7403 - loss: 0.6736 - val_accuracy: 0.6331 - val_loss: 0.9607
# Epoch 5/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 128s 1s/step - accuracy: 0.8455 - loss: 0.4347 - val_accuracy: 0.6829 - val_loss: 1.0179
# Epoch 6/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 110s 1s/step - accuracy: 0.8864 - loss: 0.3173 - val_accuracy: 0.6644 - val_loss: 1.2086
# Epoch 7/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 111s 1s/step - accuracy: 0.9389 - loss: 0.2004 - val_accuracy: 0.6678 - val_loss: 1.4352
# Epoch 8/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - accuracy: 0.9536 - loss: 0.1466 - val_accuracy: 0.6829 - val_loss: 1.4771
# Epoch 9/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 129s 1s/step - accuracy: 0.9585 - loss: 0.1280 - val_accuracy: 0.7095 - val_loss: 1.3651
# Epoch 10/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 103s 1s/step - accuracy: 0.9692 - loss: 0.1022 - val_accuracy: 0.7176 - val_loss: 1.4761
# Epoch 11/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 107s 1s/step - accuracy: 0.9827 - loss: 0.0664 - val_accuracy: 0.7199 - val_loss: 1.6629
# Epoch 12/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 119s 1s/step - accuracy: 0.9833 - loss: 0.0503 - val_accuracy: 0.7025 - val_loss: 1.5373
# Epoch 13/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 119s 1s/step - accuracy: 0.9846 - loss: 0.0616 - val_accuracy: 0.7153 - val_loss: 1.6158
# Epoch 14/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.9876 - loss: 0.0476 - val_accuracy: 0.7315 - val_loss: 1.7489
# Epoch 15/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 116s 1s/step - accuracy: 0.9923 - loss: 0.0479 - val_accuracy: 0.7431 - val_loss: 1.6454
# Epoch 16/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 115s 1s/step - accuracy: 0.9942 - loss: 0.0280 - val_accuracy: 0.7002 - val_loss: 1.9811
# Epoch 17/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 120s 1s/step - accuracy: 0.9899 - loss: 0.0469 - val_accuracy: 0.7350 - val_loss: 1.7735
# Epoch 18/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 111s 1s/step - accuracy: 0.9790 - loss: 0.0737 - val_accuracy: 0.7234 - val_loss: 1.8047
# Epoch 19/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 113s 1s/step - accuracy: 0.9904 - loss: 0.0394 - val_accuracy: 0.7164 - val_loss: 1.8672
# Epoch 20/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 110s 1s/step - accuracy: 0.9859 - loss: 0.0540 - val_accuracy: 0.7396 - val_loss: 1.7697

# %% [markdown]
# # Plot Performance

# %%
fig = plt.figure()
plt.plot(hist.history['loss'], color='teal', label='loss')
plt.plot(hist.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(hist.history['accuracy'], color='teal', label='accuracy')
plt.plot(hist.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# # Evaluate the model

# %%
from tensorflow.keras.metrics import Precision, Recall, SparseCategoricalAccuracy

# %%
pre = Precision()
re = Recall()
acc = SparseCategoricalAccuracy()

# %%
test_iter = iter(test)  # Reset the dataset iterator

for batch in test_iter: 
    X, y = batch
    yhat = model.predict(X)
    
    # Convert probabilities to class predictions
    y_pred = np.argmax(yhat, axis=1)
    
    # Update metrics with class predictions
    pre.update_state(y, y_pred)
    re.update_state(y, y_pred)
    acc.update_state(y, y_pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 819ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 2024-08-05 15:04:03.783586: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
print(pre.result(), re.result(), acc.result())
# Out:
# tf.Tensor(0.8908046, shape=(), dtype=float32) tf.Tensor(0.9037901, shape=(), dtype=float32) tf.Tensor(0.1208134, shape=(), dtype=float32)

# %%
y.shape
# Out:
# TensorShape([2])

# %%
yhat.shape
# Out:
# (2, 5)

# %% [markdown]
# # Test the Model

# %%
img = cv2.imread('test_1.jpg')
plt.imshow(img)
plt.show()

# %%
resize = tf.image.resize(img, (256,256))
plt.imshow(resize.numpy().astype(int))
plt.show()

# %%
yhat = model.predict(np.expand_dims(resize/255, 0))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step

# %%
yhat
# Out:
# array([[2.7708019e-04, 3.1761812e-07, 9.9857962e-01, 9.5795590e-19,
#         1.1430399e-03]], dtype=float32)

# %%
if yhat > 0.5: 
    print(f'Predicted class is Rose')
else:
    print(f'Predicted class is Happy')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 if yhat > 0.5:
#       2     print(f'Predicted class is Rose')
#       3 else:
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
import requests

# Function to load and preprocess the image
def load_and_preprocess_image(url):
    response = requests.get(url)
    img = Image.open(BytesIO(response.content))
    img = img.resize((224, 224))
    img_array = img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = img_array / 255.0
    return img_array

# URL of the image to predict
image_url = 'https://www.thetutuguru.com.au/wp-content/uploads/2020/07/Black-Madonna-Rose.jpg'

# Load and preprocess the image
img_array = load_and_preprocess_image(image_url)

# Predict the class of the image
prediction = model.predict(img_array)
predicted_class = np.argmax(prediction, axis=1)

# Get the class label
class_labels = train_generator.class_indices
class_labels = {v: k for k, v in class_labels.items()}
predicted_label = class_labels[predicted_class[0]]

print(f'The predicted class is: {predicted_label}')

# %% [markdown]
# # Save the Model

# %%
from tensorflow.keras.models import load_model

# %%
model.save(os.path.join('models','imageclassifier.h5'))

# %%
new_model = load_model('imageclassifier.h5')

# %%
new_model.predict(np.expand_dims(resize/255, 0))
